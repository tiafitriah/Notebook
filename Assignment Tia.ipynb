# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf  
import pandas as pd  

# Download Tesla stock data  
tesla_data = yf.download('TSLA', start='2020-01-01', end='2023-10-01')  

# Reset the index to turn the date into a column  
tesla_data.reset_index(inplace=True)  

# Display the first five rows of the DataFrame  
print(tesla_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date  Adj Close      Close       High        Low       Open  \
# Ticker                  TSLA       TSLA       TSLA       TSLA       TSLA
# 0      2020-01-02  28.684000  28.684000  28.713333  28.114000  28.299999
# 1      2020-01-03  29.534000  29.534000  30.266666  29.128000  29.366667
# 2      2020-01-06  30.102667  30.102667  30.104000  29.333332  29.364668
# 3      2020-01-07  31.270666  31.270666  31.441999  30.224001  30.760000
# 4      2020-01-08  32.809334  32.809334  33.232666  31.215334  31.580000
#
# Price      Volume
# Ticker       TSLA
# 0       142981500
# 1       266677500
# 2       151995000
# 3       268231500
# 4       467164500

# %%
pip install requests beautifulsoup4 pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 86.8 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 90.5 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 42.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests  
from bs4 import BeautifulSoup  
import pandas as pd  

# URL of the page containing Tesla's revenue data  
url = 'https://finance.yahoo.com/quote/TSLA/financials/'  

# Send a GET request to the page  
response = requests.get(url)  

# Parse the page content  
soup = BeautifulSoup(response.content, 'html.parser')  

# Locate the table containing the revenue data  
# You need to inspect the page and find the correct selector for the table  
table = soup.find('table', {'class': 'YOUR_TABLE_CLASS_OR_ID'})  

# Extract headers  
headers = []  
for header in table.find_all('th'):  
    headers.append(header.text.strip())  

# Extract rows  
rows = []  
for row in table.find_all('tr'):  
    cols = row.find_all('td')  
    cols = [ele.text.strip() for ele in cols]  
    rows.append(cols)  

# Create a DataFrame  
tesla_revenue = pd.DataFrame(rows, columns=headers)  

# Display the last five rows  
print(tesla_revenue.tail())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 20
#      18 # Extract headers
#      19 headers = []
# ---> 20 for header in table.find_all('th'):
#      21     headers.append(header.text.strip())
#      23 # Extract rows
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.2/948.2 kB 33.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 75.9 MB/s eta 0:00:00:00:01
# ...
#   Created wheel for peewee: filename=peewee-3.17.8-py3-none-any.whl size=138964 sha256=d491a08a63b7e73669217aaf6d9f50eda92c3e2311d5f3b1261861aa5bbe2caf
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/ff/6c/15/506e25bc390de450a7fa53c155cd9b0fbd13ad3e84a9abc183
# Successfully built peewee
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf  

# Download GME stock data  
gme_data = yf.download('GME', start='2020-01-01', end='2023-10-01')  

# Reset the index to turn the date into a column  
gme_data.reset_index(inplace=True)  

# Display the first five rows of the DataFrame  
print(gme_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date Adj Close   Close    High     Low    Open    Volume
# Ticker                  GME     GME     GME     GME     GME       GME
# 0      2020-01-02    1.5775  1.5775  1.6175  1.5175  1.5350  17814400
# 1      2020-01-03    1.4700  1.4700  1.5625  1.4600  1.5525  14175600
# 2      2020-01-06    1.4625  1.4625  1.4775  1.4000  1.4500  13579200
# 3      2020-01-07    1.3800  1.3800  1.4575  1.3600  1.4425  20912000
# 4      2020-01-08    1.4300  1.4300  1.4625  1.3525  1.3725  22517600

# %%
pip install requests beautifulsoup4 pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests  
from bs4 import BeautifulSoup  
import pandas as pd  

# URL of the page with GameStop's revenue data  
url = 'https://finance.yahoo.com/quote/TSLA/financials/'  

# Send a GET request to fetch the content  
response = requests.get(url)  

# Parse the HTML content  
soup = BeautifulSoup(response.content, 'html.parser')  

# Locate the table with revenue data  
# Adjust the selector based on the website's structure  
table = soup.find('table', {'class': 'YOUR_TABLE_CLASS_OR_ID'})  

# Extract headers  
headers = []  
for header in table.find_all('th'):  
    headers.append(header.text.strip())  

# Extract rows  
rows = []  
for row in table.find_all('tr'):  
    cols = row.find_all('td')  
    cols = [ele.text.strip() for ele in cols]  
    if cols:  
        rows.append(cols)  

# Create DataFrame  
gme_revenue = pd.DataFrame(rows, columns=headers)  

# Display the last five rows  
print(gme_revenue.tail())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 20
#      18 # Extract headers
#      19 headers = []
# ---> 20 for header in table.find_all('th'):
#      21     headers.append(header.text.strip())
#      23 # Extract rows
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
pip install yfinance matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.5/164.5 kB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 88.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.2/326.2 kB 33.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 93.3 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 45.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 86.9 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 13.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf  
import matplotlib.pyplot as plt  
  
def make_graph(ticker, start_date, end_date, title):  
    # Fetch the stock data  
    stock_data = yf.download(ticker, start=start_date, end=end_date)  
  
    # Plot the data  
    plt.figure(figsize=(10, 6))  
    plt.plot(stock_data.index, stock_data['Close'], label='Close Price', color='b')  
    plt.title(title)  
    plt.xlabel('Date')  
    plt.ylabel('Stock Price (USD)')  
    plt.grid(True)  
    plt.legend()  
    plt.show()  
  
# Call the function to plot Tesla stock data  
make_graph('TSLA', '2020-01-01', '2023-10-01', 'Tesla Stock Price (2020-2023)')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
pip install yfinance matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf  
import matplotlib.pyplot as plt  
  
def make_graph(ticker, start_date, end_date, title):  
    # Fetch the stock data  
    stock_data = yf.download(ticker, start=start_date, end=end_date)  
  
    # Plot the data  
    plt.figure(figsize=(10, 6))  
    plt.plot(stock_data.index, stock_data['Close'], label='Close Price', color='g')  
    plt.title(title)  
    plt.xlabel('Date')  
    plt.ylabel('Stock Price (USD)')  
    plt.grid(True)  
    plt.legend()  
    plt.show()  
  
# Call the function to plot GameStop stock data  
make_graph('GME', '2020-01-01', '2023-10-01', 'GameStop Stock Price (2020-2023)')
# Out:
# [*********************100%***********************]  1 of 1 completed
